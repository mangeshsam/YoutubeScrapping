# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = "AIzaSyBK8lYpeqqGkFgAnjLmrUqp-pkJ_HeqKHY"
#channel_id="UCOeZUa2FdnxCtcdyTdvA1vQ"
playlist_id=["UUtz9FLnr_blQ7JOeSnAJKQA"]

youtube = build("youtube","v3",developerKey=api_key)

# %%
def get_video_ids(youtube,playlist_id):
    video_ids=[]
    for i in range(0,len(video_ids),50):
        request = youtube.playlistItems().list(
            part="snippet,contentDetails,statistics",
            id = ",".join(playlist_id[i:i+50]),
            maxResults = 50)
        response=request.execute()
        for i in range(len(response["items"])):
            video_ids.append(response["items"][i]["contentDetails"]["videoId"])
        return video_ids

# %%
ids=get_video_ids(youtube,playlist_id)

# %%
ids

# %%
def get_video_ids(youtube,playlist_id):
    
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails,statistics",
        id = ",".join(playlist_id[i:i+50]),
        maxResults = 50)
    response=request.execute()
    video_ids=[]
    
    all_video_stats = []
    for i in range(0,len(video_ids),50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id = ",".join(playlist_id[i:i+50]),
            maxResults = 50)
        response=request.execute()
        for i in range(len(response["items"])):
            video_ids.append(response["items"][i]["contentDetails"]["videoId"])

    next_page_token = response.get("nextPageToken")
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages=False
        else:
            request = youtube.playlistItems().list(
                part="contentDetails",
                playlistId=playlist_id,
                maxResults = 50,
                pageToken=next_page_token)
            response=request.execute()
            for i in range(len(response["items"])):
                video_ids.append(response["items"][i]["contentDetails"]["videoId"])

            next_page_token= response.get("nextPageToken")
        
    all_video_stats = []
    for i in range(0,len(video_ids),50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id = ",".join(video_ids[i:i+50]))
        response=request.execute()
        for video in response["items"]:
            video_stats=dict(Title = video["snippet"]["title"],
                             Published_date=video["snippet"]["publishedAt"],
                             Views = video["statistics"]["viewCount"],
                             Likes = video["statistics"]["likeCount"],
                             Dislikes = video["statistics"]["favoriteCount"],
                             Comments = video["statistics"]["commentCount"])
            all_video_stats.append(video_stats)
    return all_video_stats

# %%
video_details = get_video_ids(youtube, playlist_id)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=0'>1</a> video_details = get_video_ids(youtube, playlist_id)
#
# Untitled-1.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=0'>1</a> def get_video_ids(youtube,playlist_id):
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=1'>2</a>     request = youtube.playlistItems().list(
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=2'>3</a>         part="contentDetails",
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=3'>4</a>         playlistId=playlist_id,
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=4'>5</a>         maxResults = 50)
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=5'>6</a>     response=request.execute()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=6'>7</a>     video_ids=[]
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=7'>8</a>     for i in range(len(response["items"])):
#
# File c:\Users\adm1\anaconda3\envs\YT-env\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\adm1\anaconda3\envs\YT-env\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&playlistId=%5B%27UUtz9FLnr_blQ7JOeSnAJKQA%27%5D&maxResults=50&key=AIzaSyBK8lYpeqqGkFgAnjLmrUqp-pkJ_HeqKHY&alt=json returned "The playlist identified with the request's <code>playlistId</code> parameter cannot be found.". Details: "[{'message': "The playlist identified with the request's <code>playlistId</code> parameter cannot be found.", 'domain': 'youtube.playlistItem', 'reason': 'playlistNotFound', 'location': 'playlistId', 'locationType': 'parameter'}]">

# %%
def get_video_ids(youtube,playlist_id):
    request = youtube.playlistItems().list(
        part="contentDetails",
        playlistId=playlist_id,
        maxResults = 50)
    response=request.execute()
    video_ids=[]
    for i in range(len(response["items"])):
        video_ids.append(response["items"][i]["contentDetails"]["videoId"])

    next_page_token = response.get("nextPageToken")
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages=False
        else:
            request = youtube.playlistItems().list(
                part="contentDetails",
                playlistId=playlist_id,
                maxResults = 50,
                pageToken=next_page_token)
            response=request.execute()
            def get_video_details(youtube, video_ids):

                all_video_stats = []
                for i in range(0,len(video_ids),50):
                    request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id = ",".join(video_ids[i:i+50]))
                    response=request.execute()
                    for video in response["items"]:
                        video_stats=dict(Title = video["snippet"]["title"],
                                        Published_date=video["snippet"]["publishedAt"],
                                        Views = video["statistics"]["viewCount"],
                                        Likes = video["statistics"]["likeCount"],
                                        Dislikes = video["statistics"]["favoriteCount"],
                                        Comments = video["statistics"]["commentCount"])
                        all_video_stats.append(video_stats)
                return all_video_stats

    return video_ids

# %%
ids=get_video_ids(youtube,playlist_id)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# c:\Users\adm1\youtube\Untitled-1.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> ids=get_video_ids(youtube,playlist_id)
#
# c:\Users\adm1\youtube\Untitled-1.ipynb Cell 9 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> def get_video_ids(youtube,playlist_id):
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>     request = youtube.playlistItems().list(
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>         part="contentDetails",
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>         playlistId=playlist_id,
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>         maxResults = 50)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     response=request.execute()
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>     video_ids=[]
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     for i in range(len(response["items"])):
#
# File c:\Users\adm1\anaconda3\envs\YT-env\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\adm1\anaconda3\envs\YT-env\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&playlistId=%5B%27UUtz9FLnr_blQ7JOeSnAJKQA%27%5D&maxResults=50&key=AIzaSyBK8lYpeqqGkFgAnjLmrUqp-pkJ_HeqKHY&alt=json returned "The playlist identified with the request's <code>playlistId</code> parameter cannot be found.". Details: "[{'message': "The playlist identified with the request's <code>playlistId</code> parameter cannot be found.", 'domain': 'youtube.playlistItem', 'reason': 'playlistNotFound', 'location': 'playlistId', 'locationType': 'parameter'}]">

# %%
api_key = "AIzaSyBK8lYpeqqGkFgAnjLmrUqp-pkJ_HeqKHY"
    #channel_id="UCOeZUa2FdnxCtcdyTdvA1vQ"
playlist_id=["UUtz9FLnr_blQ7JOeSnAJKQA"]

youtube = build("youtube","v3",developerKey=api_key)
request = youtube.playlistItems().list(
    part="contentDetails",
    playlistId=playlist_id,
    maxResults = 50)
response=request.execute()
video_ids=[]
for i in range(len(response["items"])):
    video_ids.append(response["items"][i]["contentDetails"]["videoId"])

next_page_token = response.get("nextPageToken")
more_pages = True
    
while more_pages:
    if next_page_token is None:
        more_pages=False
    else:
        request = youtube.playlistItems().list(
            part="contentDetails",
            playlistId=playlist_id,
            maxResults = 50,
            pageToken=next_page_token)
        response=request.execute()
return video_ids
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# c:\Users\adm1\youtube\Untitled-1.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> youtube = build("youtube","v3",developerKey=api_key)
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> request = youtube.playlistItems().list(
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>     part="contentDetails",
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>     playlistId=playlist_id,
#       <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a>     maxResults = 50)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a> response=request.execute()
#      <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a> video_ids=[]
#      <a href='vscode-notebook-cell:/c%3A/Users/adm1/youtube/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> for i in range(len(response["items"])):
#
# File c:\Users\adm1\anaconda3\envs\YT-env\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\adm1\anaconda3\envs\YT-env\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&playlistId=%5B%27UUtz9FLnr_blQ7JOeSnAJKQA%27%5D&maxResults=50&key=AIzaSyBK8lYpeqqGkFgAnjLmrUqp-pkJ_HeqKHY&alt=json returned "The playlist identified with the request's <code>playlistId</code> parameter cannot be found.". Details: "[{'message': "The playlist identified with the request's <code>playlistId</code> parameter cannot be found.", 'domain': 'youtube.playlistItem', 'reason': 'playlistNotFound', 'location': 'playlistId', 'locationType': 'parameter'}]">
